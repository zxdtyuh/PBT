# %%
# import time
import pandas
import numpy as np
import scipy as sp
from scipy.differentiate import derivative
from scipy.interpolate import RegularGridInterpolator
import matplotlib.pyplot as plt
#import matplotlib.colors as colors
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
#import time
from BraggLI import j_int
from GaussLI_Andy_edit import G_int

# %%
# %matplotlib tk

# %%
# ===============================================================
# True functions
# ===============================================================

c_p = 0.43
c_beta = 833.33333333
c_gamma = 0.6
std = 1/np.sqrt(2)
mean = 0


def F( x , v_B ):
  return 1 / ( np.power( x , c_p ) + v_B )

@np.vectorize
def f( x , v_B ):
  return sp.integrate.quad( lambda u: F( u , v_B )  , 0 , x )[0]
  
def h( x , v_B ):
  return ( x + c_beta ) * F( x , v_B ) 

def j( x , v_B ):
  val = h( x , v_B ) + ( c_gamma * f( x , v_B ) )
  return val

def G(x):
    return (1/(std * np.sqrt(2))) * np.exp(-(x - mean)**2 / (2 * std**2))

# %%
###################################################################################################################
# Start of table stuff
###################################################################################################################

nodes = {"Old7" :
    [0.025446043828620757,
    0.12923440720030277,
    0.2970774243113014,
    0.5,
    0.7029225756886985,
    0.8707655927996972,
    0.9745539561713792],



 "New15" : [-0.991455371120813, -0.949107912342759, -0.864864423359769,  # 15 node from -1 to 1
         -0.741531185599394, -0.586087235467691, -0.405845151377397, 
         -0.207784955007898, 0.000000000000000, 0.207784955007898,
         0.405845151377397, 0.586087235467691, 0.741531185599394,
         0.864864423359769, 0.949107912342759, 0.991455371120813], 

 "New31" :[
    -0.998002298693397, -0.987992518020485, -0.967739075679139,
    -0.937273392400706,  -0.897264532344082, -0.848206583410427,
    -0.790418501442466,  -0.724417731360170, -0.650996741297417,
    -0.570972172608539,  -0.485081863640240, -0.394151347077563,
    -0.299180007153169,  -0.201194093997435, -0.101142066918717,
     0.000000000000000,
     0.101142066918717,   0.201194093997435,  0.299180007153169,
     0.394151347077563,   0.485081863640240,  0.570972172608539,
     0.650996741297417,   0.724417731360170,  0.790418501442466,
     0.848206583410427,   0.897264532344082,  0.937273392400706,
     0.967739075679139,   0.987992518020485,  0.998002298693397,
],

"New51" : [
    -0.999262104992609834193456682342677,
    -0.995556969790498097908784946893902,
    -0.988035794534077247637331014577406,
    -0.976663921459517511498315386479594,
    -0.961614986425842512418130033660167,
    -0.942974571228974339414011169658471,
    -0.920747115281701561746902729959369,
    -0.894991997878275368851042006782805,
    -0.865847065293275595448996969588340,
    -0.833442628760834001421021108693570,
    -0.797873797998500059410410904994307,
    -0.759259263037357630577282865204361,
    -0.717766406813084388186654079773298,
    -0.673566368473468364485120633247622,
    -0.626810099010317412788122681624518,
    -0.577662930241222967723689841612654,
    -0.526325284334719182599623778158010,
    -0.473002731445714960522182115009192,
    -0.417885382193037748851814394594572,
    -0.361172305809387837735821730127641,
    -0.303089538931107830167478909980339,
    -0.243866883720988432045190362797452,
    -0.183718939421048892015969888759528,
    -0.122864692610710396387359818808037,
    -0.061544483005685078886546392366797,
    0.000000000000000000000000000000000,
    0.061544483005685078886546392366797,
    0.122864692610710396387359818808037,
    0.183718939421048892015969888759528,
    0.243866883720988432045190362797452,
    0.011099234735633305, 0.011270151119025159, 0.011433494443919896,
    0.01158933131205966, 0.011737334379655462, 0.011877251718258887,
    0.01200918308658586, 0.012133168855745547, 0.012248957262950085,
    0.01235636248354813, 0.012455456316305968, 0.012546259313322372,
    0.012628588486756643, 0.012702320571632227, 0.012767506493035503,
    0.012824151155653347, 0.012872135887416617, 0.012911397968074625,
    0.012941972073001826, 0.012963849781855072, 0.01297697396705299,
    0.012981341669818429,
    0.01297697396705299, 0.012963849781855072, 0.012941972073001826,
    0.012911397968074625, 0.012872135887416617, 0.012824151155653347,
    0.012767506493035503, 0.012702320571632227, 0.012628588486756643,
    0.012546259313322372, 0.012455456316305968, 0.01235636248354813,
    0.012248957262950085, 0.012133168855745547, 0.01200918308658586,
    0.011877251718258887, 0.011737334379655462, 0.01158933131205966,
    0.011433494443919896, 0.011270151119025159, 0.011099234735633305,
    0.01092060718456572, 0.010734592108287894, 0.010541602704562452,
    0.010341536808964776, 0.010134202825015324, 0.009920004692636349,
    0.009699457135023369, 0.00947240902050502, 0.009238592839432007,
    0.00899850591418247, 0.008752789034152622, 0.00850122264787977,
    0.008243428901001774, 0.007980018724670064, 0.0077117990182068805,
    0.007438452811721081, 0.007159436077213953, 0.006875505461537651,
    0.006587703301856719, 0.006295570209381478, 0.00599829819323993,
    0.005696842464708509, 0.005392611421021911, 0.005084929924302581,
    0.004772535067774519, 0.004456670926076444, 0.00413939057898402,
    0.0038196789390504303, 0.0034953812283214656, 0.0031681826710811124,
    0.0028415015539956074, 0.002513794278486187, 0.0021807331946234465,
    0.0018445610671780654, 0.0015126526391069834, 0.0011833055734878273,
    0.0008444082933476886, 0.0004947855579769631, 0.00017654676004238585,
]}


###################################################################################################################
# End of table stuff
###################################################################################################################

# %%
vb_real = 0.44
vb_start = 0.4

vr = 100
vb = vb_real - vb_start
#vSig = 0.012 * vr**(0.9353) 
vSig = 58.926 * vr**(-0.9353) 
z =  40

measure_bits = 20
output_bits = 20

NoN = "New51"  # number of nodes


n = 6 # number of standard deviations away from the gaussian you want to be


# for i in range(len(nodes)):
#    KronrodWeights[i] = (n / np.sqrt(2)) * KronrodWeights[i]
#    nodes[i] = (n / np.sqrt(2)) * nodes[i] + z

for i in range(len(nodes[NoN])):
  KronrodWeights[NoN][i] = int(KronrodWeights[NoN][i] * 2**36) / 2**36
  nodes[NoN][i] = int(nodes[NoN][i] * 2**36) / 2**36



scaled_vr = int((2**11) * (vr))
scaled_vb = int((2**20) * vb)
scaled_vSig = int((2**18) * (vSig))
#scaled_vSigold = int((2**18) * (vSigold))
scaled_z = int((2**11) * z)

# print(scaled_vr)
# print(scaled_vb)
# print(scaled_vSig)
# print(scaled_z)

#print(j_int(((full_x_range) * (520947 / (2**20))) + x_start, ((full_y_range) * (300102 / (2**20))) + y_start))


vr_in = scaled_vr / 2**11
vb_in = scaled_vb / 2**20 + vb_start
vSig_in = scaled_vSig / 2**18
#vSigold_in = scaled_vSigold / 2**18
z_in = scaled_z / 2**11

# print(vr_in)
# print(vb_in)
# print(vSig_in)
# print(z_in)


#print("G values:")
#print("j values:")
#print("Gj values:")

def Qexact(vr, vb, vsig, z):
  return sp.integrate.quad( lambda u: j(vr - u, vb) * G(vsig * (z - u))  , 0 , vr )[0]

def Qexact2(vr, vb, vsig, z):
  return sp.integrate.quad( lambda u: j(vr * (1 - u), vb) * G(vsig * (z - vr * u))  , 0 , 1 )[0]

# New Q to integrate depending on have many standard deviations you are away in the gaussian
def Q_exact3(vr, vb, vsig, z):
   return sp.integrate.quad( lambda u: j(vr - z + (u), vb) * G(u * vsig)  , (z - vr), z )[0]


def Q(vr, vb, vsig, z):
  Q = 0
  for i in range(len(nodes[NoN])):
      Q += KronrodWeights[NoN][i] * j(vr * (1 - nodes[NoN][i]), vb) * G(vsig * (z - vr * nodes[NoN][i]))
      #print(vSig_in * (z_in - (vr_in * nodes[i])))
      #print(G(vSig_in * (z_in - (vr_in * nodes[i]))))
      #print(vr_in * (1 - nodes[i]))
      #print(j(vr_in * (1 - nodes[i]), vb_in))
      #print(G(vSig_in * (z_in - (vr_in * nodes[i]))) * j(vr_in * (1 - nodes[i]), vb_in))
  return(Q)

def Q_int3(vr, vb, vsig, z):  # New Kronrod estimation
  Q = 0
  adjnodes = np.zeros(len(nodes[NoN]))
  adjKronrodWeights = np.zeros(len(KronrodWeights[NoN]))

  b = min(n * (np.sqrt(2) * vsig)**(-1), z)
  a = max(z - vr, -n * (np.sqrt(2) * vsig)**(-1))

  for i in range(len(adjnodes)):
     adjnodes[i] = (nodes[NoN][i] + 1) * ((b - a) / 2) + a
     adjKronrodWeights[i] = (KronrodWeights[NoN][i] / 2) * (b - a)


  for i in range(len(adjnodes)):
      Q += adjKronrodWeights[i] * j_int(vr - z + adjnodes[i], vb) * G_int(adjnodes[i] * vsig)
  return(Q)

def QGK(vr, vb, vsig, z):
  Qint = 0
  for i in range(len(nodes[NoN])):
      Qint += KronrodWeights[NoN][i] * j_int(vr * (1 - nodes[NoN][i]), vb) * G_int(vsig * (z - vr * nodes[NoN][i]))
  return(Qint)

# %%
print(QGK(vr_in, vb_in, vSig_in, z_in))
# Out:
# 1.1426331368082814

# %%
zplot = np.linspace( 0, 400, 1000 )
y1 = np.vectorize( Q_exact3 )(vr_in, vb_in, vSig_in, zplot)
y2 = np.vectorize( Q_int3 )(vr_in, vb_in, vSig_in, zplot)
# Out:
# C:\Users\samdha\AppData\Local\Temp\ipykernel_52508\3920122202.py:67: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   return sp.integrate.quad( lambda u: j(vr - z + (u), vb) * G(u * vsig)  , (z - vr), z )[0]

# %%
fig, (ax1, ax2) = plt.subplots(2)
ax1.plot(zplot, y1)
ax1.plot(zplot, y2, linestyle='dashed')
ax1.set_title(rf"Comparison of updated Gauss-Kronrod and exact Q(z) {len(nodes[NoN])} nodes, N = {n}, $v_R$ = {vr}")
# ax1.set_xlabel()
ax1.set_ylabel('Q')
ax2.plot(zplot, y1 - y2)
ax2.set_title(rf"Difference between updated Gauss-Kronrod and exact Q(z) using {len(nodes[NoN])} nodes, N = {n}, $v_R$ = {vr}")
ax2.set_xlabel("z")
ax2.set_ylabel('Q')

plt.show()
